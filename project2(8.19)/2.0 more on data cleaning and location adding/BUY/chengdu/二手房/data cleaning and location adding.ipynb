# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
df = pd.read_csv('成都二手房数据.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (6,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (208642, 25)

# %%
lst_loc = []
lst_loc_old = df['house_location'].tolist()
for i in range(len(lst_loc_old)):
    templst = lst_loc_old[i].split('二手房成交')[0:]
    templst = [j.replace(",", "") for j in templst][1:-1]
    templst.insert(0, "成都")
    ''.join(templst)
    lst_loc.append(' '.join(templst))

# %%
df['house_location'] = lst_loc

# %%
list_location = df['house_location'].value_counts().index.tolist()

# %%
dict_location = {}
Key = '6b95b84cab6100c0a6f52c62ece97e4b'
My_key = 'f654d644aeae0e1da847d7ca408f4370'
url_pre = 'https://restapi.amap.com/v3/geocode/geo?key={}&address={}&city={}'
counter = 0
for i in list_location:
    location = i.split(" ")[-1]
    url = url_pre.format(Key, location, '成都')
    res = requests.get(url).json()
    if res['status'] == '0':
        dict_location[i] = np.nan
        counter +=1
    else:
        try: 
            dict_location[i] = res['geocodes'][0]['location']
            if counter % 250 == 0:
                print('one batch(250) processed')
        except:
            dict_location[i] = np.nan
            
        counter +=1
# Out:
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed

# %%
df['location_coords'] = np.nan

# %%
counter = 0
for i in list_location:
    counter += 1
    df_temp = df[df['house_location'] == i]
    df_temp_index = df_temp.index.tolist()
    df.iloc[df_temp_index,25] = dict_location[i]
    if counter %50 == 0:
        print('A batch(50) is done')
# Out:
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done

# %%
df.head()
# Out:
#   Architectural_Types Built_up_area Completion_date Cover_area Decoration  \
# 0                  塔楼        41.13㎡            2007       暂无数据         精装
# 1                  板楼           42㎡            2000       暂无数据         其他
# 2                  塔楼         41.5㎡            2003       暂无数据         精装
# 3                  塔楼        41.13㎡            2007       暂无数据         精装
# 4                  板楼        38.61㎡            2004       暂无数据         精装
#
#   Equipped_with_elevators Heating_mode House_orientation House_use  \
# 0                       有          NaN              暂无数据      普通住宅
# 1                       无          NaN               南 北      普通住宅
# 2                       有          NaN              暂无数据      普通住宅
# 3                       有          NaN              暂无数据      普通住宅
# 4                       有          NaN                 北      普通住宅
#
#   Housing_type          ...               floor             headline  \
# 0     1室1厅0厨1卫          ...           低楼层(共22层)  兴元绿洲一期 1室1厅 41.13平米
# 1     2室1厅1厨1卫          ...            低楼层(共7层)   燃灯寺东街14号 2室1厅 42平米
# 2     1室0厅0厨1卫          ...           低楼层(共12层)     幸福时光 1室0厅 41.5平米
# 3     1室1厅0厨1卫          ...           低楼层(共22层)  兴元绿洲一期 1室1厅 41.13平米
# 4     1室0厅0厨1卫          ...           低楼层(共26层)    长富新城 1室0厅 38.61平米
#
#       house_location house_price_perunit house_price_tenK  \
# 0    成都 金牛 金府 兴元绿洲一期                7489               31
# 1  成都 武侯 双楠 燃灯寺东街14号                7810               33
# 2      成都 武侯 丽都 幸福时光                6892               29
# 3    成都 金牛 金府 兴元绿洲一期                7294               30
# 4    成都 青羊 宽窄巷子 长富新城                9040               35
#
#   house_website_traffic household_ratio_perstair      sell_date  \
# 0                  暂无数据                     两梯八户  2012.11.13 成交
# 1                  暂无数据                     一梯三户  2015.08.04 成交
# 2                  暂无数据                    四梯十七户  2013.01.14 成交
# 3                  暂无数据                     两梯八户  2012.11.21 成交
# 4                  暂无数据                     三梯十户  2012.06.25 成交
#
#                                                  url       location_coords
# 0  https://cd.lianjia.com/chengjiao/CD0000665367....  104.047083,30.716167
# 1  https://cd.lianjia.com/chengjiao/CDWH88558154....  104.039322,30.644588
# 2  https://cd.lianjia.com/chengjiao/CD0000665474....  104.048385,30.711859
# 3  https://cd.lianjia.com/chengjiao/CD0000665360....  104.047083,30.716167
# 4  https://cd.lianjia.com/chengjiao/CD0000670020....  104.048793,30.664620
#
# [5 rows x 26 columns]

# %%
len(df)
# Out:
# 208642

# %%
df.to_csv('成都二手房地址数据.csv', encoding = 'utf-8-sig',index = False)

# %%
df.columns
# Out:
# Index(['Architectural_Types', 'Built_up_area', 'Completion_date', 'Cover_area',
#        'Decoration', 'Equipped_with_elevators', 'Heating_mode',
#        'House_orientation', 'House_use', 'Housing_type', 'Huxing_structure',
#        'Ownership_of_housing', 'Transaction_Ownership',
#        'Years_of_Property_Rights', 'Years_of_housing', 'building_structure',
#        'floor', 'headline', 'house_location', 'house_price_perunit',
#        'house_price_tenK', 'house_website_traffic', 'household_ratio_perstair',
#        'sell_date', 'url', 'location_coords'],
#       dtype='object')

# %%
url = 'https://sh.shop.fang.com/shou/house/d220-i31/'
print(url.split('i3')[0][:-1])
# Out:
# https://sh.shop.fang.com/shou/house/d220
