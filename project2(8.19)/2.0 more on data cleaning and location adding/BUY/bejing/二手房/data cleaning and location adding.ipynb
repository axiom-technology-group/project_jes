# %%
import pandas as pd
import numpy as np
import requests

# %%
df = pd.read_csv('北京二手房数据.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (674339, 25)

# %%
df.head(2)
# Out:
#   Architectural_Types Built_up_area Completion_date Cover_area Decoration  \
# 0                  板楼        92.83㎡            2012     74.12㎡         精装
# 1                板塔结合        89.22㎡            2012     70.58㎡         精装
#
#   Equipped_with_elevators Heating_mode House_orientation House_use  \
# 0                       有         集中供暖                东南      普通住宅
# 1                       有          自供暖               北 南      普通住宅
#
#   Housing_type                        ...                          \
# 0     2室1厅1厨1卫                        ...
# 1     3室1厅1厨1卫                        ...
#
#   building_structure      floor              headline  \
# 0               钢混结构  低楼层(共14层)     金地仰山 2室1厅 92.83平米
# 1               钢混结构  中楼层(共20层)  长阳国际城一区 3室1厅 89.22平米
#
#                                house_location house_price_perunit  \
# 0   北京房产网,北京二手房成交,大兴二手房成交,高米店南二手房成交,金地仰山二手房成交                 NaN
# 1  北京房产网,北京二手房成交,房山二手房成交,长阳二手房成交,长阳国际城一区二手房成交                 NaN
#
#   house_price_tenK house_website_traffic household_ratio_perstair  \
# 0              428                    14                     两梯四户
# 1              393                   615                     两梯四户
#
#        sell_date                                                url
# 0  2019.08.12 成交  https://bj.lianjia.com/chengjiao/101105416222....
# 1  2019.08.12 成交  https://bj.lianjia.com/chengjiao/101105158195....
#
# [2 rows x 25 columns]

# %%
lst_loc = []
lst_loc_old = df['house_location'].tolist()
for i in range(len(lst_loc_old)):
    templst = lst_loc_old[i].split('二手房成交')[0:]
    templst = [j.replace(",", "") for j in templst][1:-1]
    templst.insert(0, "北京")
    ''.join(templst)
    lst_loc.append(' '.join(templst))

# %%
df['house_location'] = lst_loc

# %%
list_location = df['house_location'].value_counts().index.tolist()

# %%
dict_location = {}
Key = '6b95b84cab6100c0a6f52c62ece97e4b'
My_key = 'f654d644aeae0e1da847d7ca408f4370'
url_pre = 'https://restapi.amap.com/v3/geocode/geo?key={}&address={}&city={}'
counter = 0
for i in list_location:
    location = i.split(" ")[-1]
    url = url_pre.format(Key, location, '北京')
    res = requests.get(url).json()
    if res['status'] == '0':
        dict_location[i] = np.nan
        counter +=1
    else:
        try: 
            dict_location[i] = res['geocodes'][0]['location']
            if counter % 250 == 0:
                print('one batch(250) processed')
        except:
            dict_location[i] = np.nan
            
        counter +=1
# Out:
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed

# %%
df['location_coords'] = np.nan
counter = 0
for i in list_location:
    counter += 1
    df_temp = df[df['house_location'] == i]
    df_temp_index = df_temp.index.tolist()
    df.iloc[df_temp_index,25] = dict_location[i]
    if counter %50 == 0:
        print('A batch(50) is done')
# Out:
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done

# %%
df['house_location'][1]
# Out:
# '北京 房山 长阳 长阳国际城一区'

# %%
df['location_coords'][1]
# Out:
# '116.215894,39.758093'

# %%
dict_location['北京 房山 长阳 长阳国际城一区']
# Out:
# '116.215894,39.758093'

# %%
df.head()
# Out:
#   Architectural_Types Built_up_area Completion_date Cover_area Decoration  \
# 0                  板楼        92.83㎡            2012     74.12㎡         精装
# 1                板塔结合        89.22㎡            2012     70.58㎡         精装
# 2                板塔结合        94.89㎡            1998       暂无数据         简装
# 3                  板楼        29.73㎡            2009     12.72㎡         其他
# 4                  板楼        95.08㎡            2003     81.93㎡         毛坯
#
#   Equipped_with_elevators Heating_mode House_orientation House_use  \
# 0                       有         集中供暖                东南      普通住宅
# 1                       有          自供暖               北 南      普通住宅
# 2                       有         集中供暖               南 北      普通住宅
# 3                       有          自供暖                 北        车库
# 4                       无         集中供暖               南 北      普通住宅
#
#   Housing_type          ...               floor              headline  \
# 0     2室1厅1厨1卫          ...           低楼层(共14层)     金地仰山 2室1厅 92.83平米
# 1     3室1厅1厨1卫          ...           中楼层(共20层)  长阳国际城一区 3室1厅 89.22平米
# 2     3室1厅1厨1卫          ...           中楼层(共13层)   西马金润二区 3室1厅 94.89平米
# 3           车位          ...                 地下室      远洋沁山水 车位 29.73平米
# 4     2室1厅1厨1卫          ...            中楼层(共7层)   翠屏北里西区 2室1厅 95.08平米
#
#      house_location house_price_perunit house_price_tenK  \
# 0   北京 大兴 高米店南 金地仰山                 NaN              428
# 1  北京 房山 长阳 长阳国际城一区                 NaN              393
# 2  北京 丰台 马家堡 西马金润二区                 NaN              468
# 3   北京 石景山 鲁谷 远洋沁山水                 NaN               40
# 4   北京 通州 果园 翠屏北里西区                 NaN              402
#
#   house_website_traffic household_ratio_perstair      sell_date  \
# 0                    14                     两梯四户  2019.08.12 成交
# 1                   615                     两梯四户  2019.08.12 成交
# 2                  2676                     四梯两户  2019.08.12 成交
# 3                  1408                     暂无数据  2019.08.12 成交
# 4                   229                     一梯两户  2019.08.12 成交
#
#                                                  url       location_coords
# 0  https://bj.lianjia.com/chengjiao/101105416222....  116.313611,39.764432
# 1  https://bj.lianjia.com/chengjiao/101105158195....  116.215894,39.758093
# 2  https://bj.lianjia.com/chengjiao/101104219086....  116.381303,39.838893
# 3  https://bj.lianjia.com/chengjiao/101104670171....  116.250392,39.902012
# 4  https://bj.lianjia.com/chengjiao/101105363661....  116.646788,39.889617
#
# [5 rows x 26 columns]

# %%
df.to_csv('北京二手房地址数据.csv', encoding = 'utf-8-sig',index = False)
