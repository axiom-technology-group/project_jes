# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('fangtianshangquansh1.csv')
df2 = pd.read_csv('fangtianxiashangquansh.csv')
df3 = pd.read_csv('fangtianxiashangquansh2.csv')
df4 = pd.read_csv('fangtianxiashangquansh3.csv')
df5 = pd.read_csv('fangtianxiashangquansh4.csv')
df6 = pd.read_csv('fangtianxiashangquansh5.csv')
df7 = pd.read_csv('fangtianxiashangquansh6.csv')
df8 = pd.read_csv('fangtianxiashangquansh7.csv')
df9 = pd.read_csv('fangtianxiashangquansh8.csv')
df10 = pd.read_csv('fangtianxiashangquansh9.csv')
df11 = pd.read_csv('fangtianxiashangquansh10.csv')
df12 = pd.read_csv('fangtianxiashangquansh11.csv')
df13 = pd.read_csv('fangtianxiashangquansh12.csv')
df14 = pd.read_csv('fangtianxiashangquansh13.csv')
df15 = pd.read_csv('fangtianxiashangquansh14.csv')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15])

# %%
df.drop_duplicates(subset = 'url',keep = 'first', inplace = True)

# %%
df.shape
# Out:
# (16394, 18)

# %%
df.to_csv('上海商圈数据.csv',index = False, encoding = 'utf-8-sig')

# %%
df.head()
# Out:
#   cenggao     floor                                   function_list  \
# 0   4.50米  第2层(共2层)                网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,燃气
# 1   5.00米  第1层(共1层)  网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,可明火,排烟,排污,燃气,外摆区
# 2   4.50米       90㎡  网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,可明火,排烟,排污,燃气,外摆区
# 3   5.20米  第2层(共6层)  网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,可明火,排烟,排污,燃气,外摆区
# 4   4.50米  第1层(共1层)                   网络,停车位,上水,下水,可明火,排烟,排污,燃气,外摆区
#
#   jianzhumianji jinshen location   loupandizhi loupanmingcheng miankuan  \
# 0         1000㎡  15.00米    青浦,徐泾        绿地世界中心          绿地世界中心   60.00米
# 1         82.6㎡  10.00米    嘉定,南翔          南翔老街          南翔老街商铺    8.00米
# 2           98㎡   9.00米   徐汇,徐家汇          天钥桥路            天钥桥路   10.00米
# 3        188.5㎡  16.00米   徐汇,徐家汇     肇嘉浜路1115号             美罗城   12.00米
# 4       159.67㎡  14.90米   长宁,北新泾  长宁北新泾北渔路天山西路       北渔路沿街餐饮商铺   10.00米
#
#          release_date service_price shangpu_type shifoufenge  \
# 0  2019/8/24 12:42:53     0.00元/㎡·月      写字楼配套底商           否
# 1  2019/8/16 11:42:25     3.00元/㎡·月         临街门面           否
# 2  2019/8/14 11:13:56     5.00元/㎡·月        商业街商铺           否
# 3   2019/8/7 11:57:23    25.00元/㎡·月      购物中心/百货           否
# 4  2019/8/22 20:16:49     5.00元/㎡·月         临街门面           是
#
#                              shihejingying  \
# 0                                     百货超市
# 1                 百货超市,生活服务,美容美发,餐饮美食,休闲娱乐
# 2  美容美发,餐饮美食,服饰鞋包,生活服务,酒店宾馆,家居建材,百货超市,休闲娱乐
# 3            百货超市,服饰鞋包,生活服务,美容美发,餐饮美食,休闲娱乐
# 4  百货超市,酒店宾馆,家居建材,服饰鞋包,生活服务,美容美发,餐饮美食,休闲娱乐
#
#                                 titile total_price  \
# 0            2/10/17号地铁虹桥国家会展中心，虹桥世界中心       4500万
# 1     南翔老街入口（全家）年租25万,重餐饮,老板回笼资金，给钱就卖！        258万
# 2  9号线地铁口+ 纯沿街+品牌商家+ 来伊份+即买收租+ 年租4房东急售        560万
# 3   9号线 徐家汇 美罗城 转角大开间 星巴克 年租金90万 急售！！！        600万
# 4     70年独立产权+北渔路沿街餐饮门面+大开间重餐饮+稳定年租58万        770万
#
#                                               url zhuangxiu
# 0  https://sh.shop.fang.com/shou/3_360333589.html       简装修
# 1  https://sh.shop.fang.com/shou/3_359479506.html       精装修
# 2  https://sh.shop.fang.com/shou/3_359235355.html       简装修
# 3  https://sh.shop.fang.com/shou/3_358547073.html       精装修
# 4  https://sh.shop.fang.com/shou/3_360141795.html       精装修

# %%
df = pd.read_csv('上海商圈数据.csv')

# %%
def havemi(string):
    if "米" in string and len(string) <= 7:
        return True
    else:
        return False
        

df['pend'] = df['loupandizhi'].apply(havemi)

list_index = df[df['pend'] == True].index.tolist()

df_temp = df[df['pend'] == True]

df_temp.head()
# Out:
#     cenggao      floor                                   function_list  \
# 60      NaN  第2层(共10层)                                             NaN
# 123     NaN   第1层(共1层)               网络,暖气,停车位,中央空调,上水,下水,可明火,排烟,排污,燃气
# 134     NaN   第1层(共3层)                                             NaN
# 146     NaN   第1层(共1层)  网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,可明火,排烟,排污,燃气,外摆区
# 171     NaN   第1层(共2层)                                             NaN
#
#     jianzhumianji jinshen location loupandizhi loupanmingcheng miankuan  \
# 60           150㎡   4.00米    青浦,徐泾      15.00米            盈港东路   10.00米
# 123          122㎡   7.00米   徐汇,漕河泾      15.00米         钦州北路桂林路    8.00米
# 134          135㎡   5.00米    闵行,华漕      10.00米        北翟路2000弄   16.00米
# 146          110㎡   5.50米   青浦,朱家角       8.00米       淀山湖大道851号   13.00米
# 171          105㎡   3.00米   静安,不夜城       1.00米  西藏北路180号（曲阜路口）    1.00米
#
#            release_date service_price shangpu_type shifoufenge shihejingying  \
# 60   2019/8/10 15:34:53    25.00元/㎡·月      写字楼配套底商           是        虹桥世界中心
# 123  2019/8/28 10:16:51     0.00元/㎡·月        商业街商铺           是        钦州北路商铺
# 134   2019/7/9 10:46:43     5.00元/㎡·月         住宅底商           是        虹桥一号商铺
# 146  2019/6/20 11:16:07    18.00元/㎡·月        商业街商铺           是         青浦万达茂
# 171  2019/8/24 18:52:12     5.00元/㎡·月         住宅底商           是         上海大悦城
#
#                                titile total_price  \
# 60              国家会展中心在售旺铺，虹桥商务区正核心位置        700万
# 123  徐汇 漕河泾 钦州北路桂林路70年产权铺 和住宅一样价格 纯一楼        719万
# 134              新出好铺子不等人，周边都是商务楼 人流量        500万
# 146                  青浦商业广场、5.5米、一楼沿街        530万
# 171                8/12号线大悦城纯一楼，展示面品牌        518万
#
#                                                 url zhuangxiu  pend
# 60   https://sh.shop.fang.com/shou/3_358905447.html        毛坯  True
# 123  https://sh.shop.fang.com/shou/3_360679372.html       简装修  True
# 134  https://sh.shop.fang.com/shou/3_355683609.html       精装修  True
# 146  https://sh.shop.fang.com/shou/3_353976008.html       精装修  True
# 171  https://sh.shop.fang.com/shou/3_360357733.html       简装修  True

# %%
list_loupandizhi = df_temp['loupandizhi'].tolist()

df.iloc[list_index,8] = list_loupandizhi

list_loupanmingcheng = df_temp['loupanmingcheng'].tolist()

df.iloc[list_index,6] = list_loupanmingcheng

list_shihejingying = df_temp['shihejingying'].tolist()

df.iloc[list_index,7] = list_shihejingying

df.iloc[list_index,13] = np.nan

list_miankuan = df_temp['miankuan'].tolist()

df.iloc[list_index,4] = list_miankuan

list_jinshen = df_temp['jinshen'].tolist()

df.iloc[list_index,0] = list_jinshen

def delshangpu(string):
    if '商铺' in string:
        return string.replace('商铺','').strip()
    
    elif '餐饮街铺' in string:
        return string.replace('餐饮街铺','').strip()
    
    elif '?' in string:
        return string.replace('?','').strip()
    
    elif '\r\n' in string:
        return string.replace('\r\n','').strip()
            
    else:
        return string.strip()

df['loupanmingcheng'] = df['loupanmingcheng'].apply(delshangpu)

list_temp = df['loupanmingcheng'].tolist()
list_temp2 = df['location'].tolist()
list_location = []
for i in range(len(list_temp)):
    list_location.append(str(list_temp2[i])+','+str(list_temp[i]))
df['location'] = list_location

del df['pend']

df_temp = df.copy()

def haveceng(string):
    if '层' in str(string):
        return str(string)
    else:
        return np.nan
df['floor'] = df_temp['floor'].apply(haveceng)

def havem2(string):
    if '㎡' in str(string):
        return str(string)
    else:
        return np.nan
df['shiyongmianji'] = df_temp['floor'].apply(havem2)

# %%
def nottolong(string):
    if len(string) > 16:
        return False
    else:
        return True

df = df[df['loupanmingcheng'].apply(nottolong)]

# %%
df.to_csv('上海商圈数据.csv',index = False, encoding = 'utf-8-sig')

# %%
df['function_list'][0]
# Out:
# '网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,燃气'
