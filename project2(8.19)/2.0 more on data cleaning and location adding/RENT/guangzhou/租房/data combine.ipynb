# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('rent_gz.csv')
df2 = pd.read_csv('广州租房地址.csv')

# %%
df = pd.merge(left=df1,right=df2, how='left', left_on='url', right_on='url')

# %%
df.head()
# Out:
#   Built_up_area Huxing_structure chaoxiang chuzufangshi    floor  \
# 0           93㎡           2室2厅2卫        朝南           整租  高楼层/15层
# 1          117㎡           3室2厅2卫        朝北           整租  高楼层/28层
# 2          122㎡           3室2厅2卫        朝北           整租  中楼层/12层
# 3           76㎡           2室2厅1卫        朝东           整租  高楼层/31层
# 4           30㎡           1室1厅1卫       朝东南           整租  低楼层/12层
#
#   function_list have_elvator have_parkingspace         headline  \
# 0           NaN            有              暂无数据   整租·合和新城 2室2厅 南
# 1           NaN            有              暂无数据  整租·祈福辉煌台 3室2厅 北
# 2           NaN            有              暂无数据   整租·航都花园 3室2厅 北
# 3           NaN            有              暂无数据   整租·时尚广场 2室2厅 东
# 4           NaN            有              暂无数据  整租·海德花园 1室1厅 东南
#
#    house_website_traffic      ...      rental_pirce       ruzhu   sell_date  \
# 0                      4      ...              2900        随时入住  2019-09-10
# ...

# %%
df.shape
# Out:
# (35596, 22)

# %%
# Out:
#    Built_up_area Huxing_structure chaoxiang chuzufangshi    floor  \
# 0            93㎡           2室2厅2卫        朝南           整租  高楼层/15层
# 1           117㎡           3室2厅2卫        朝北           整租  高楼层/28层
# 2           122㎡           3室2厅2卫        朝北           整租  中楼层/12层
# 3            76㎡           2室2厅1卫        朝东           整租  高楼层/31层
# 4            30㎡           1室1厅1卫       朝东南           整租  低楼层/12层
# 5           135㎡           4室2厅2卫        朝南           整租  中楼层/33层
# 6           109㎡           3室1厅1卫       朝东南           整租  中楼层/28层
# 7            94㎡           3室2厅2卫       朝东南           整租  中楼层/33层
# 8            70㎡           2室1厅1卫       朝东南           整租   中楼层/8层
# 9           103㎡           3室2厅2卫       朝东北           整租  中楼层/27层
# 10           43㎡           1室1厅1卫      朝南 北           整租  中楼层/27层
# 11          104㎡           3室1厅1卫       朝东南           整租  中楼层/28层
# 12          100㎡           3室2厅2卫       朝西南           整租  高楼层/28层
# ...

# %%
df.to_csv('广州租房数据.csv',index = False, encoding = 'utf-8-sig')
