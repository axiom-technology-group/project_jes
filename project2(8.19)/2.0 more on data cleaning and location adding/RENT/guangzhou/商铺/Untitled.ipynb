# %%
import pandas as pd

df = pd.read_csv('sp_gz_rent.csv',error_bad_lines=False)

# %%
df.shape
# Out:
# (770, 22)

# %%
df.to_csv('广州商铺数据.csv',index = False, encoding = 'utf-8-sig')

# %%
df.head()
# Out:
#   zhuanrangfei rental_price pay_method jianzhumianji shiyongmianji  \
# 0          NaN     69480元/月         月付          772㎡           NaN
# 1          NaN     24000元/月         月付         77.5㎡           NaN
# 2          NaN         1元/月         面议          400㎡           NaN
# 3          NaN       300元/月         月付          380㎡           NaN
# 4          NaN     36000元/月         面议          150㎡           NaN
#
#   shengyuzuqi zhuanrangfangshi     floor  \
# 0         NaN              NaN  第2层(共3层)
# 1         NaN              NaN  第1层(共2层)
# 2         NaN              NaN  第1层(共1层)
# 3         NaN              NaN  第1层(共2层)
# 4         NaN              NaN  第1层(共1层)
#
#                                   zhuangxiu building_type  \
# 0   精装修\r\n                                      购物中心/百货
# 1   精装修\r\n                                         住宅底商
# 2  简单装修\r\n                                        商业街商铺
# 3   精装修\r\n                                        商业街商铺
# ...
