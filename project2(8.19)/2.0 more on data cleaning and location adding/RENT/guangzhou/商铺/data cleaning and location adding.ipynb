# %%
import pandas as pd
import numpy as np
import requests
df = pd.read_csv('广州商铺数据.csv',error_bad_lines=False)

# %%
lst_lpname = df['loupanmingcheng'].value_counts().index.tolist()

lst_lploc = df['loupandizhi'].value_counts().index.tolist()

# %%
city = '广州'
dict_location = {}
My_key = 'f654d644aeae0e1da847d7ca408f4370'
url_pre = 'https://restapi.amap.com/v3/geocode/geo?key={}&address={}&city={}'
counter = 0
for i in range(len(lst_lpname)):
    location = lst_lpname[i]
    url = url_pre.format(My_key, location, city)
    res = requests.get(url).json()
    if res['status'] == '0':
        location = lst_lploc[i]
        url = url_pre.format(My_key, location, city)
        res = requests.get(url).json()
        if res['status'] == '0':
            dict_location[lst_lpname[i]] = np.nan
            counter +=1
        else:
            try: 
                dict_location[lst_lpname[i]] = res['geocodes'][0]['location']
                if counter % 250 == 0:
                    print('one batch(250) processed')
            except:
                dict_location[lst_lpname[i]] = np.nan
            
    else:
        try: 
            dict_location[lst_lpname[i]] = res['geocodes'][0]['location']
            if counter % 250 == 0:
                print('one batch(250) processed')
        except:
            location = lst_lploc[i]
            url = url_pre.format(My_key, location, city)
            res = requests.get(url).json()
            if res['status'] == '0':
                dict_location[lst_lpname[i]] = np.nan
                counter +=1
            else:
                try: 
                    dict_location[lst_lpname[i]] = res['geocodes'][0]['location']
                    if counter % 250 == 0:
                        print('one batch(250) processed')
                except:
                    dict_location[lst_lpname[i]] = np.nan
            
        counter +=1
# Out:
# one batch(250) processed

# %%
dict_location
# Out:
# {'\r\n                                    500平方火锅餐馆南沙区出租 ': '113.525165,22.801624',
#  '\r\n                                    hom&you ': '113.270792,23.116171',
#  '\r\n                                    mooly+house美甲 ': '113.260376,23.182858',
#  '\r\n                                    mooly美甲店 ': '113.395652,23.127688',
#  '\r\n                                    七星市场 ': '113.600313,23.539289',
#  '\r\n                                    三元里抗英大街商场 ': '113.261664,23.156653',
#  '\r\n                                    不二碗云吞店 ': '113.265633,23.084950',
#  '\r\n                                    东一城 ': nan,
#  '\r\n                                    东哥客栈 ': '113.344750,23.124125',
#  '\r\n                                    东方汇广场 ': '113.445589,23.186366',
#  '\r\n                                    东浚荔景商城首层美食区 ': '113.324803,23.135971',
#  '\r\n                                    中华广场 ': '113.282671,23.125676',
#  '\r\n                                    中大布匹市场 ': '113.294044,23.085867',
#  '\r\n                                    中新知识城万科幸福誉三期 ': '113.620015,23.288097',
#  '\r\n                                    中鼎君和名城 ': '113.454642,23.107663',
#  '\r\n                                    人民中路344号金贝儿童装 ': '113.253492,23.120822',
#  '\r\n                                    仁济路 ': '113.255375,23.109192',
#  '\r\n                                    从化上城湾畔 ': '113.588629,23.528702',
#  '\r\n                                    众惠市场二楼家私城 ': '113.414680,23.672625',
#  '\r\n                                    佛山市南海区丹灶镇农贸市场转让 ': '113.222570,23.150457',
#  '\r\n                                    佛山陶瓷总部 ': '113.270313,23.106070',
#  '\r\n                                    保利i立方 ': '113.619559,23.191799',
#  '\r\n                                    保利克洛维 ': '113.320528,23.126984',
#  '\r\n                                    保利学府里 ': '113.440848,23.103409',
#  '\r\n                                    信藏漫画 ': '113.222531,23.396286',
#  '\r\n                                    光塔路 ': '113.257491,23.123184',
#  '\r\n                                    六天酒店 ': '113.446372,23.103559',
#  '\r\n                                    六运小区 ': '113.323074,23.130121',
#  '\r\n                                    农贸批发市场 ': '113.274802,23.230441',
#  '\r\n                                    凤仪东路 ': '113.585397,23.541358',
#  '\r\n                                    出租 ': '113.206396,23.071665',
#  '\r\n                                    创基丽江国际 ': '113.820878,23.271798',
#  '\r\n                                    南岗地铁站 ': '113.365641,23.015962',
#  '\r\n                                    南村综合市场 ': '113.388918,23.006271',
#  '\r\n                                    南约新街 ': '113.290481,23.077608',
#  '\r\n                                    叫了个炸鸡 ': '113.374764,23.129740',
#  '\r\n                                    同福西龙溪首约街铺 ': '113.255500,23.103000',
#  '\r\n                                    听风者服装店 ': '113.272909,23.135976',
#  '\r\n                                    均禾五金市场 ': '113.259442,23.254096',
#  '\r\n                                    城中村 ': '113.467116,23.104078',
#  '\r\n                                    增城区中新镇新市路 ': '113.620687,23.286806',
#  '\r\n                                    增城合汇商业广场 ': '113.769125,23.186018',
#  '\r\n                                    增城荔城街荔城大道西南二巷1号 ': '113.781283,23.281069',
#  '\r\n                                    复兴南路私伙焗 ': '113.272177,23.121359',
#  '\r\n                                    大沙头二马路+临街马路+门前停车位 ': '113.282709,23.116148',
#  '\r\n                                    大石文化艺术园 ': '113.305110,23.023933',
#  '\r\n                                    天成路60-72号 ': '113.255701,23.113851',
#  '\r\n                                    天河区天平架沿街出租 ': '113.318791,23.160871',
#  '\r\n                                    天河区太石科影时代出租楼盘 ': '113.361200,23.124680',
#  '\r\n                                    天河区计经大楼 ': '113.322714,23.146035',
#  '\r\n                                    天河天河客运站元岗临街门面 ': '113.342309,23.170892',
#  '\r\n                                    天河客运站 ': '113.342309,23.170892',
#  '\r\n                                    天河棠下 ': '113.379002,23.126587',
#  '\r\n                                    太和兴和市场和珊社区居委会 ': '113.351083,23.296763',
#  '\r\n                                    奢茶店 ': '113.273289,23.157290',
#  '\r\n                                    姬利美容 ': '113.236059,23.428936',
#  '\r\n                                    宝华豪庭 ': '113.241468,23.114402',
#  '\r\n                                    宝华路宝华豪庭 ': '113.241468,23.114402',
#  '\r\n                                    尊茶 ': '113.361406,23.444753',
#  '\r\n                                    小黄龙日用品超市 ': '113.244376,23.115896',
#  '\r\n                                    市桥小区 ': '113.390732,23.116541',
#  '\r\n                                    平石小区 ': '113.232385,23.420076',
#  '\r\n                                    广东中信建江集团有限公司 ': '113.247409,23.131954',
#  '\r\n                                    广东农信大厦 ': '113.344035,23.125541',
#  '\r\n                                    广东省广州市海珠区同福东路569号 ': '113.266940,23.106856',
#  '\r\n                                    广东省广州市海珠区同福东路598号 ': '113.267574,23.106669',
#  '\r\n                                    广东省广州市海珠区慎和大街8号-3 ': '113.268819,23.098827',
#  '\r\n                                    广东省广州市番禺区头庙路11号 ': '113.259705,22.985454',
#  '\r\n                                    广东省广州市番禺区泰安路17号 ': '113.421371,22.950923',
#  '\r\n                                    广东省广州市花都区 ': '113.220218,23.404165',
#  '\r\n                                    广东省广州市荔湾区墩兴西街 ': '113.244261,23.125981',
#  '\r\n                                    广垦商务大厦 ': '113.334061,23.152251',
#  '\r\n                                    广州三元里出租 ': '113.258968,23.157817',
#  '\r\n                                    广州中山八路荔景商城 ': '113.240520,23.125915',
#  '\r\n                                    广州伊士丹顿酒店有限公司 ': '113.374158,23.115536',
#  '\r\n                                    广州南站 ': '113.267080,22.988342',
#  '\r\n                                    广州官洲北苑旁 ': '113.372694,23.084558',
#  '\r\n                                    广州市光复北路首层 ': '113.253331,23.126320',
#  '\r\n                                    广州市大德路 ': '113.258184,23.117947',
#  '\r\n                                    广州市大新大厦1 ': '113.257386,23.115959',
#  '\r\n                                    广州市大新大厦2 ': '113.257386,23.115959',
#  '\r\n                                    广州市康公街底商 ': '113.276975,23.100754',
#  '\r\n                                    广州市建设三马路 ': '113.283197,23.133217',
#  '\r\n                                    广州市番禺区市桥街长堤东路425号 ': '113.376662,22.928232',
#  '\r\n                                    广州市白云区圣雅堡 ': '113.222773,23.150579',
#  '\r\n                                    广州市白云路 ': '113.632300,23.362903',
#  '\r\n                                    广州市荔湾区上下九步行街招 ': '113.249463,23.115127',
#  '\r\n                                    广州市荔湾区上下九美食广场 ': '113.241982,23.115623',
#  '\r\n                                    广州市高第街临商 ': '113.266200,23.118388',
#  '\r\n                                    广州市黄浦区黄埔东路3999号 ': '113.461905,23.100687',
#  '\r\n                                    广州纳金科技 ': '113.504610,23.153610',
#  '\r\n                                    广州龙洞商业步行街旁招租 ': '113.364984,23.195493',
#  '\r\n                                    广钢商圈中海花湾壹号 ': '113.379298,23.129899',
#  '\r\n                                    建和中心 ': '113.321219,23.136018',
#  '\r\n                                    恒业大厦 ': '113.355834,23.123704',
#  '\r\n                                    手工糕点 ': '113.360195,22.950488',
#  '\r\n                                    捷登都会商场 ': '113.265649,23.125756',
#  '\r\n                                    敏捷金谷国际五金交易中心 ': '113.350506,23.124913',
#  '\r\n                                    新塘保利东江 ': '113.623968,23.121412',
#  '\r\n                                    新塘白江底商 ': '113.623968,23.121412',
#  '\r\n                                    新市主街双门面奶茶店转让 ': '113.388417,22.975885',
#  '\r\n                                    新滘东路赤沙东约临街靓铺 ': '113.347925,23.079723',
#  '\r\n                                    时代方州临街 ': '113.352150,23.117314',
#  '\r\n                                    时光奶茶小吃 ': nan,
#  '\r\n                                    昌岗中路转让 ': '113.275290,23.089002',
#  '\r\n                                    朝阳东路 ': '113.322830,23.026706',
#  '\r\n                                    杨箕 ': '113.261883,23.157084',
#  '\r\n                                    柒分食健身餐轻食沙拉 ': '113.290640,23.216944',
#  '\r\n                                    树德小马驹创意园 ': '113.297962,23.332638',
#  '\r\n                                    格风发廊 ': '113.285587,23.086742',
#  '\r\n                                    棠下水果店 ': '113.257943,23.169380',
#  '\r\n                                    水果拼盘 ': '113.513901,22.832881',
#  '\r\n                                    海港花园 ': '113.346470,23.097568',
#  '\r\n                                    海珠区岗园街89-4 ': '113.338797,23.089772',
#  '\r\n                                    海珠区市二宫地铁口出口 ': '113.269636,23.106964',
#  '\r\n                                    海珠区鹭江西街9号 ': '113.307381,23.093091',
#  '\r\n                                    海珠状元坊 ': '113.259621,23.113080',
#  '\r\n                                    淘服装 ': '113.260360,23.187300',
#  '\r\n                                    清华居 ': '113.256222,23.186206',
#  '\r\n                                    清布商圈核心 ': '113.526296,23.086410',
#  '\r\n                                    滨江东临街 ': '113.295549,23.068470',
#  '\r\n                                    潮汕板筋饭 ': '113.349453,23.007481',
#  '\r\n                                    潮美味 ': '113.250787,23.111224',
#  '\r\n                                    熊霸港式小食 ': '113.273819,23.095932',
#  '\r\n                                    牛利岗 ': '113.322924,23.170074',
#  '\r\n                                    猪三爷 ': '113.395652,23.127688',
#  '\r\n                                    珠村 ': '113.422108,23.122744',
#  '\r\n                                    珠玑路陈塘南底商 ': '113.243612,23.111087',
#  '\r\n                                    瑶台花园 ': '113.252236,23.161695',
#  '\r\n                                    番禺南村镇雅居乐附近 ': '113.379100,23.003863',
#  '\r\n                                    番禺南村雅居乐附近 ': '113.358313,23.013208',
#  '\r\n                                    番禺大学城立德街方圆时光 ': '113.405292,23.039609',
#  '\r\n                                    番禺太石科影时代的店铺楼盘 ': '113.400720,22.880992',
#  '\r\n                                    白云区三元里抗英大街 ': '113.267187,23.162749',
#  '\r\n                                    白云区望岗创展中心一楼临街 ': '113.273289,23.157290',
#  '\r\n                                    白云区瑶台富民城超市附近 ': '113.252066,23.157478',
#  '\r\n                                    石溪新业路福全街 ': '113.284275,23.066294',
#  '\r\n                                    神明商业广场 ': '113.453950,23.099750',
#  '\r\n                                    科创8号创意园 ': '113.376976,23.136248',
#  '\r\n                                    粤嘉包 ': '113.448627,23.104616',
#  '\r\n                                    粤色茶颜 ': '113.282671,23.125676',
#  '\r\n                                    紫金楼 ': '113.268683,23.098841',
#  '\r\n                                    纽恩泰增城总部大楼 ': '113.324516,23.167401',
#  '\r\n                                    线上花甲 ': '113.337417,23.097915',
#  '\r\n                                    缅甸腾龙娱乐开户 ': '113.363001,22.904547',
#  '\r\n                                    美荔汇、 ': '113.247852,23.125539',
#  '\r\n                                    花城美汇 ': '113.214929,23.375679',
#  '\r\n                                    花都区商业大道 ': '113.231863,23.386017',
#  '\r\n                                    花都工厂食堂档口 ': '113.164922,23.378617',
#  '\r\n                                    花都清布金纳大厦店面 ': '113.217571,23.374503',
#  '\r\n                                    花都科技 ': '113.174441,23.459116',
#  '\r\n                                    苹果体验店 ': '113.261613,23.194347',
#  '\r\n                                    茂名市茂南区油城三路 ': '113.275515,23.122465',
#  '\r\n                                    荔湾区芳村花蕾路红棉小区 ': '113.229908,23.090315',
#  '\r\n                                    荔湾速邦车城大型场地 ': '113.243000,23.127500',
#  '\r\n                                    融创万达文化旅 ': '113.361200,23.124680',
#  '\r\n                                    西丽商业城 ': '113.352866,22.939600',
#  '\r\n                                    豪瑞达 ': '113.322830,23.026706',
#  '\r\n                                    财富大厦 ': '113.242078,23.151159',
#  '\r\n                                    财富天地 ': '113.243975,23.149028',
#  '\r\n                                    越秀可逸江畔 ': '113.363001,22.904547',
#  '\r\n                                    车陂南C出口 ': '113.395548,23.124465',
#  '\r\n                                    转角店铺 ': '113.384129,22.937244',
#  '\r\n                                    轻食g义 ': '113.269535,23.094765',
#  '\r\n                                    金星大厦 ': '113.347222,23.143984',
#  '\r\n                                    金沙创展 ': '113.222942,23.273942',
#  '\r\n                                    金满城地铺 ': '113.329883,23.145383',
#  '\r\n                                    金融街融穗御府 ': '113.506222,23.213086',
#  '\r\n                                    金豪商场 ': '113.307474,23.100966',
#  '\r\n                                    金迪大厦500平 ': '113.312223,23.128193',
#  '\r\n                                    金骊城 ': nan,
#  '\r\n                                    金骊城商场 ': '113.304043,23.221436',
#  '\r\n                                    银丰电子商务大厦 ': '113.283016,23.236922',
#  '\r\n                                    锦泰商行 ': '113.294794,23.068656',
#  '\r\n                                    锦绣半岛销售中心 ': '113.256701,23.041756',
#  '\r\n                                    锦绣花园北区 ': '113.309490,22.971755',
#  '\r\n                                    长盛国际时尚中心 ': '113.244107,23.191607',
#  '\r\n                                    雅居乐花语集 ': '113.191036,23.414643',
#  '\r\n                                    飞晟汇inface ': '113.501000,23.171923',
#  '\r\n                                    骏和广场 ': '113.360195,22.950488',
#  '\r\n                                    鱼珠 ': '113.514661,23.112908',
#  '\r\n                                    龙骏广场风情街 ': '113.226321,23.178750',
#  '0平': '113.325057,23.126164',
#  '264000平': '113.311182,23.142415',
#  '5号停机坪': '113.264940,23.183470',
#  '万寿路': '113.281441,23.102073',
#  '万科云城米酷商铺': '113.225792,23.178367',
#  '万科里': '113.279292,23.082544',
#  '万达广场广州番禺店': '113.350019,23.013712',
#  '上下九商业步行街': '113.246035,23.113888',
#  '上渡路': '113.308422,23.100995',
#  '下渡路商铺': '113.309108,23.098931',
#  '东南综合市场': '113.387964,23.131386',
#  '东圃摩登城': '113.400463,23.117348',
#  '东山口署前路商铺': '113.295064,23.123291',
#  '东方广场商铺': '113.294818,23.133898',
#  '东晓路': '113.283408,23.096123',
#  '东风东临街商铺': '113.342035,23.116691',
#  '东风东路与福今路交叉口': '113.302737,23.131723',
#  '东风西路': '113.237415,23.137697',
#  '中华广场商铺': '113.282671,23.125676',
#  '中山8路38号': '113.236569,23.124692',
#  '中山二路': '113.291572,23.125089',
#  '中山四路商铺': '113.276872,23.127270',
#  '中山大道中商铺': '113.409315,23.119753',
#  '中海花城湾商铺': '113.332129,23.117574',
#  '乐从国际家私城': nan,
#  '乐雅苑商铺': '113.360017,23.123293',
#  '五羊新城': '113.313764,23.117434',
#  '五羊邨': '113.304737,23.119490',
#  '亚太银座商铺': '113.607937,23.128865',
#  '京溪路': '113.326911,23.183555',
#  '人和 华通广场': '113.295674,23.334345',
#  '从化环城路商铺': '113.581428,23.552816',
#  '佛山千灯湖金融高新区海五路28号（千灯湖地铁站D出口）': '113.271715,23.085880',
#  '佳润广场': '113.320900,23.181107',
#  '保利V座商铺': '113.326899,23.121979',
#  '先烈中路商业裙楼商铺4楼': '113.306029,23.146242',
#  '兴国路': '113.330985,23.122454',
#  '兴盛路步行街': '113.317172,23.140393',
#  '农林下路商铺': '113.297758,23.129123',
#  '利雅湾商铺': '113.328942,23.116355',
#  '力讯商务中心': '113.304191,23.131313',
#  '力迅上筑商铺': '113.343096,23.115673',
#  '北京南路': '113.270792,23.116171',
#  '北京路/惠福东路路口': '113.265005,23.120463',
#  '北京路步行街': '113.269225,23.119908',
#  '十三行路': '113.252599,23.111069',
#  '华利路': '113.315918,23.117225',
#  '华夏路': '113.321305,23.120970',
#  '华庭路5号 一楼商铺': '113.329883,23.145383',
#  '华强路商铺': '113.318917,23.125913',
#  '华景新城商铺': '113.363788,23.141032',
#  '华景路': '113.359828,23.141047',
#  '华穗路': '113.318059,23.123333',
#  '华观路与高唐路交汇处A1栋': '113.403452,23.171609',
#  '南685阁屏商务大厦': '113.275825,23.175096',
#  '南亭大道/南亭村大街(路口)': '113.389117,23.037799',
#  '南华中路': '113.258483,23.105293',
#  '南岗': '113.541845,23.094536',
#  '南沙金茂湾商铺': '113.520807,22.779997',
#  '叠翠峰花园': '113.520916,22.796638',
#  '合生广场商铺': '113.313985,23.086002',
#  '同福东路': '113.266473,23.106595',
#  '后天河北东站商圈财润国际大厦': '113.334923,23.149975',
#  '喜龙市场': '113.166644,23.456837',
#  '嘉禾望岗': '113.280573,23.256482',
#  '地铁黄边站': '113.287122,23.217544',
#  '多宝路': '113.233728,23.116420',
#  '多宝路商铺': '113.233728,23.116420',
#  '大学城北': '113.375635,23.052832',
#  '天娱广场商铺': '113.339926,23.135718',
#  '天寿路': '113.332533,23.145403',
#  '天河东路商铺': '113.332959,23.127943',
#  '天河中区兴国...': '113.324444,23.117783',
#  '天河北广州大道中超甲级五星级酒店附属商业裙楼': '113.315912,23.132627',
#  '天河北广州大道中超甲级写字楼五星级酒店附属商业裙楼': '113.315912,23.132627',
#  '天河北路': '113.335554,23.141826',
#  '天河北路都市华庭': '113.329002,23.140651',
#  '天河区珠江新城西区华成路': '113.326120,23.124340',
#  '天河南二路': '113.331013,23.131676',
#  '天河南石牌桥太古汇旁': '113.331393,23.133804',
#  '天河城': '113.322054,23.131969',
#  '天河路': '113.326433,23.132963',
#  '太古仓': '113.253960,23.090244',
#  '奥园冠军城商铺': '113.364091,22.910144',
#  '奥园康威广场商铺': '113.633676,23.153277',
#  '奥园海景城商铺': '113.539573,22.799679',
#  '学府雅苑商铺': '113.866228,23.237564',
#  '宝业路商铺': '113.264060,23.091292',
#  '客梯0个，货梯0个': nan,
#  '客梯0个，货梯1个': '113.348264,22.990528',
#  '客梯28个，货梯2个': '113.353192,22.915846',
#  '客梯4个，货梯0个': '113.465839,23.170378',
#  '客梯4个，货梯2个': '113.273727,23.096689',
#  '客梯8个，货梯2个': '113.251460,23.104795',
#  '客梯9个，货梯2个': '113.313764,23.117434',
#  '富力盈凯广场': '113.321822,23.118572',
#  '富力金港城商铺': '113.359673,23.457762',
#  '寰城海航广场': '113.328743,23.142097',
#  '寺右二马路商铺': '113.310217,23.117361',
#  '尚东宏御': '113.344241,23.116937',
#  '尚层国际商务-正门': '113.321695,23.141713',
#  '岗贝路商铺': '113.259203,23.180330',
#  '岭南新世界商铺': '113.294304,23.232100',
#  '工业大道中商铺': '113.292616,23.057962',
#  '工业大道北106-108号': '113.259136,23.088180',
#  '市桥大南路商铺': '113.267025,23.118798',
#  '广东白云学院': '113.208619,23.271294',
#  '广东省广州市天河区花城大道20号': '113.318205,23.118712',
#  '广东省广州市海珠区江南西路68号': '113.269535,23.094765',
#  '广东省广州市番禺区坑口路5号': '113.375722,22.940983',
#  '广东省广州市番禺区大学城中心北大街': '113.384598,23.053089',
#  '广东省广州市番禺区迎星东路': '113.376971,22.969229',
#  '广园西路商铺': '113.253783,23.154626',
#  '广州北站': '113.203794,23.377405',
#  '广州北站汽车客运站-东南门': '113.204971,23.376447',
#  '广州国际贸易中心商铺': '113.323533,23.142046',
#  '广州大道北商铺': '113.313317,23.150569',
#  '广州天河区体育西路189号': '113.321140,23.138860',
#  '广州市越秀区水荫路119号三楼商业裙楼': '113.311182,23.142415',
#  '广州市黄埔区九龙大道腾飞一街2号': '113.541518,23.335732',
#  '广州渔人码头商铺': '113.295916,23.049024',
#  '广州番禺九优金融大厦': '113.264434,23.129162',
#  '广州百货大厦': '113.321196,23.137388',
#  '广州融创茂': '113.264434,23.129162',
#  '广州远洋大厦': '113.318242,23.119090',
#  '应元路': '113.270345,23.135182',
#  '康王北路903号': '113.248251,23.131303',
#  '建设五马路': '113.284340,23.135680',
#  '建设六马路': '113.285073,23.135614',
#  '御景壹號': '113.272909,23.135976',
#  '德政中路商铺': '113.275515,23.122465',
#  '怡港花园商铺': '113.454048,23.099438',
#  '恒大山水城商铺': '113.616645,23.296087',
#  '恒福路': '113.288538,23.143698',
#  '惠福东风味食街': '113.269290,23.121777',
#  '惠福路商业街': '113.259186,23.120797',
#  '招商城市主场商铺': '113.352078,23.011266',
#  '捷登都会商场': '113.265649,23.125756',
#  '文冲地铁口商业楼一楼商铺': '113.468732,23.103556',
#  '文昌南路商铺': '113.244376,23.115896',
#  '新塘镇': '113.620606,23.119342',
#  '新港东路商铺': '113.337417,23.097915',
#  '新港西路商铺': '113.305308,23.095136',
#  '时尚天河商业广场': '113.323714,23.133875',
#  '旺城大道商铺': '113.569805,23.557034',
#  '昌岗中路小区商铺': '113.271715,23.085880',
#  '昌岗路': '113.274375,23.088349',
#  '明珠苑商铺': '113.207235,23.399423',
#  '易发商业街': '113.361443,22.941187',
#  '星汇云锦商铺': '113.316604,23.121921',
#  '星汇园商铺': '113.319921,23.122713',
#  '星河湾五期': '113.350816,23.033518',
#  '星辰财富港': '113.318835,23.118089',
#  '晋和广场白云美食购物中心': '113.288157,23.237269',
#  '林乐路商铺': '113.330199,23.143427',
#  '棠石路': '113.368816,23.124134',
#  '正佳广场': '113.327990,23.132189',
#  '永福路商铺': '113.301104,23.144978',
#  '汇景新城社区商铺': '113.830623,23.284519',
#  '江南大道中商铺': '113.272467,23.099809',
#  '江南汇美食广场': '113.365081,23.195292',
#  '江南西A-出口': '113.273727,23.096689',
#  '江南西商铺': '113.273727,23.096689',
#  '江燕路商铺': '113.275672,23.075332',
#  '沙太中路商铺': '113.332573,23.177591',
#  '沙太北路独栋商业楼': '113.342460,23.205740',
#  '沙面北街商铺': '113.244419,23.107937',
#  '沿江中路': '113.304588,23.026075',
#  '泰安北路1号': '113.388496,23.130905',
#  '泰康路/侨光路路口': '113.267350,23.115151',
#  '泰沙肉菜市场': '113.281479,23.071617',
#  '泰沙路商铺': '113.285857,23.085577',
#  '洛溪': '113.299093,23.042837',
#  '海珠区新业路38号': '113.285085,23.066071',
#  '海珠摄影基地': '113.347003,23.082134',
#  '淘金大厦商铺': '113.287353,23.143696',
#  '滨江东金雅苑商铺': '113.293391,23.102948',
#  '滨海路街铺': '113.827894,23.280286',
#  '猎德大道': '113.333451,23.121060',
#  '珠光新城御景商铺': '113.320962,23.119737',
#  '珠村东横一路2号-1': '113.423216,23.117878',
#  '珠江太阳城广场商铺': '113.344838,23.124730',
#  '珠江新城东区商铺': '113.327343,23.119274',
#  '珠江新城中区商铺': '113.327343,23.119274',
#  '珠江新城华强路1号': '113.315967,23.126889',
#  '珠江新城西区商铺': '113.327343,23.119274',
#  '琶洲会展世界城商铺': '113.385892,23.095977',
#  '琶洲商业广场商铺': '113.383905,23.098788',
#  '番禺万达广场商铺': '113.349106,23.007572',
#  '白云万达广场商铺': '113.264917,23.172898',
#  '白云区': '113.273289,23.157290',
#  '白云区X271(均禾大道)': '113.300804,23.253348',
#  '白云尚城': '113.284430,23.212634',
#  '石基商铺': '113.436957,22.950673',
#  '神山工业园镇中北路63号': '113.187225,23.337513',
#  '禺山大道商铺': '113.364558,22.940305',
#  '粤垦路': '113.333377,23.149614',
#  '纸行路': '113.254976,23.121052',
#  '花城大道': '113.352806,23.117050',
#  '花城大道商铺': '113.352806,23.117050',
#  '花城汇': '113.325057,23.126164',
#  '花都区': '113.220218,23.404165',
#  '花都宝华路商铺': '113.215031,23.389067',
#  '花都旧区': '113.217571,23.374503',
#  '芳村大道中商铺': '113.224269,23.103380',
#  '荔园地产中心商铺': '113.351267,23.010265',
#  '萝岗万达广场商铺': '113.465038,23.168278',
#  '萝岗奥园广场商铺': '113.496645,23.173559',
#  '贝岗村大街与大学城中大东二路交叉口': '113.393013,23.060668',
#  '财富世纪广场商铺': '113.340682,23.124310',
#  '财富公馆商铺': '113.240960,23.151231',
#  '越秀区 华乐路': '113.288172,23.133960',
#  '车陂brt周边': '113.395548,23.124465',
#  '车陂城中村': '113.467116,23.104078',
#  '车陂路商铺': '113.392198,23.126335',
#  '都市华庭商铺': '113.329002,23.140651',
#  '金亿广场': '113.261467,23.152076',
#  '金峰地铁站-A口': '113.451182,23.181468',
#  '金沙洲': '113.201424,23.165328',
#  '金沙湾商铺': '113.352102,22.912240',
#  '金满城购物广场-西区': '113.281479,23.071617',
#  '金碧华府商铺': '113.342021,23.116720',
#  '金菊路': '113.313048,23.101073',
#  '金迪大厦商铺': '113.312223,23.128193',
#  '钟村商贸城': '113.314921,22.982079',
#  '银汇华庭商铺': '113.345063,23.143964',
#  '锐丰中心商铺': '113.501460,23.173506',
#  '锦博智慧小镇': '113.274507,23.096111',
#  '长堤大马路': '113.258860,23.112346',
#  '飞晟汇': '113.503772,23.170358',
#  '马场路': '113.343620,23.119040',
#  '骏景路散盘': '113.386413,23.123522',
#  '黄埔东路商铺': '113.494294,23.086193',
#  '黄埔大道中商铺': '113.359000,23.124814',
#  '黄埔大道西路': '113.319291,23.128241',
#  '黄浦开发区': '113.393013,23.060668',
#  '黄石路商铺': '113.271550,23.204598',
#  '黄花岗商业街': '113.297333,23.138833',
#  '黄阁汽车小镇': '113.515770,22.827328',
#  '龙口东路': '113.341012,23.144881',
#  '龙岐路商铺': '113.353192,22.915846',
#  '龙归金铂广场': '113.294105,23.267473',
#  '龙洞步行街': '113.366650,23.194679',
#  '龙津东路': '113.249992,23.121832'}

# %%
df['location_coords'] = np.nan

counter = 0
for i in lst_lpname:
    counter += 1
    df_temp = df[df['loupanmingcheng'] == i]
    df_temp_index = df_temp.index.tolist()
    df.iloc[df_temp_index,22] = dict_location[i]
    if counter %50 == 0:
        print('A batch(50) is done')
# Out:
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done

# %%
df.to_csv('广州商铺地址数据.csv', encoding = 'utf-8-sig',index = False)

# %%
df.head()
# Out:
#   zhuanrangfei rental_price pay_method jianzhumianji shiyongmianji  \
# 0          NaN     69480元/月         月付          772㎡           NaN
# 1          NaN     24000元/月         月付         77.5㎡           NaN
# 2          NaN         1元/月         面议          400㎡           NaN
# 3          NaN       300元/月         月付          380㎡           NaN
# 4          NaN     36000元/月         面议          150㎡           NaN
#
#   shengyuzuqi zhuanrangfangshi     floor  \
# 0         NaN              NaN  第2层(共3层)
# 1         NaN              NaN  第1层(共2层)
# 2         NaN              NaN  第1层(共1层)
# 3         NaN              NaN  第1层(共2层)
# 4         NaN              NaN  第1层(共1层)
#
#                                   zhuangxiu building_type  \
# 0   精装修\r\n                                      购物中心/百货
# 1   精装修\r\n                                         住宅底商
# 2  简单装修\r\n                                        商业街商铺
# 3   精装修\r\n                                        商业街商铺
# 4  简单装修\r\n                                         住宅底商
#
#            ...                                                 loupandizhi  \
# 0          ...           \r\n                                    开创大道彩文...
# 1          ...           \r\n                                    广州市荔湾区...
# 2          ...              \r\n                                    太石工业区
# 3          ...           \r\n                                    捷登都会商场...
# 4          ...           \r\n                                    金沙路现代一...
#
#   miankuan jinshen cenggao elvator_number service_price    function_list  \
# 0      NaN     NaN     NaN            NaN           NaN     网络,停车位,客梯,货梯
# 1      NaN     NaN     NaN            NaN           NaN               网络
# 2      NaN     NaN     NaN            NaN           NaN  网络,暖气,停车位,客梯,货梯
# 3      NaN     NaN     NaN            NaN           NaN        停车位,客梯,货梯
# 4      NaN     NaN     NaN            NaN           NaN           网络,停车位
#
#          release_date                                          url  \
# 0  2019/8/17 10:26:54  https://gz.shop.fang.com/zu/1_52136560.html
# 1  2019/7/30 11:36:40  https://gz.shop.fang.com/zu/1_52134272.html
# 2  2019/7/29 21:22:31  https://gz.shop.fang.com/zu/1_52134226.html
# 3  2019/7/30 12:07:01  https://gz.shop.fang.com/zu/1_52134278.html
# 4  2019/7/30 14:04:22  https://gz.shop.fang.com/zu/1_52134285.html
#
#         location_coords
# 0  113.501000,23.171923
# 1  113.379298,23.129899
# 2  113.525165,22.801624
# 3  113.265649,23.125756
# 4  113.222942,23.273942
#
# [5 rows x 23 columns]
