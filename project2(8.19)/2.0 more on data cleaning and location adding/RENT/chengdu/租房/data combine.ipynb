# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('rent_cd.csv')
df2 = pd.read_csv('成都租房地址.csv')

# %%
df = pd.merge(left=df1,right=df2, how='left', left_on='url', right_on='url')

# %%
df.head()
# Out:
#   Built_up_area Huxing_structure chaoxiang chuzufangshi    floor  \
# 0           76㎡           2室2厅1卫        朝南           整租   12/32层
# 1           93㎡           3室1厅1卫        朝南           整租  低楼层/32层
# 2          141㎡           3室2厅2卫        朝南           整租   中楼层/4层
# 3          112㎡           3室2厅1卫        朝南           整租   42/47层
# 4           94㎡           2室2厅1卫        朝南           整租   35/42层
#
#                      function_list have_elvator have_parkingspace  \
# 0  电视,冰箱,洗衣机,空调,热水器,床,暖气,宽带,衣柜,天然气            有              暂无数据
# 1                              NaN            有              暂无数据
# 2                              NaN            无              暂无数据
# 3        电视,冰箱,洗衣机,空调,热水器,床,衣柜,天然气            有              租用车位
# 4        电视,冰箱,洗衣机,空调,热水器,床,衣柜,天然气            有              租用车位
#
#              headline  house_website_traffic       ...        rental_pirce  \
# 0    整租·中洲锦城湖岸 2室2厅 南                      4       ...                5200
# ...

# %%
df.shape
# Out:
# (54963, 22)

# %%
df.to_csv('成都租房数据.csv',index = False, encoding = 'utf-8-sig')
