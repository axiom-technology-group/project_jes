# %%
import pandas as pd

df = pd.read_csv('sp_cd_rent.csv',error_bad_lines=False)

# %%
df.shape
# Out:
# (484, 22)

# %%
df.to_csv('成都商铺数据.csv',index = False, encoding = 'utf-8-sig')

# %%
df.head()
# Out:
#   zhuanrangfei rental_price pay_method jianzhumianji shiyongmianji  \
# 0          6万元      5000元/月       押一付二           38㎡           NaN
# 1          NaN      8000元/月         季付          320㎡           NaN
# 2          NaN     17000元/月        半年付          100㎡           NaN
# 3          NaN     56000元/月         面议          800㎡          700㎡
# 4          NaN     10000元/月      租金已包含            暂无           NaN
#
#   shengyuzuqi zhuanrangfangshi     floor  \
# 0         2个月              NaN  第1层(共1层)
# 1         NaN              NaN  第2层(共3层)
# 2         NaN              NaN  第1层(共1层)
# 3         NaN              NaN  第2层(共3层)
# 4         NaN              NaN       精装修
#
#                                  zhuangxiu building_type  \
# 0  精装修\r\n                                         临街门面
# 1  精装修\r\n                                         临街门面
# 2                                      简装修         商业街商铺
# 3                                      简装修          临街门面
# 4                                       其他             否
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#                                  loupanmingcheng  \
# 0  \r\n                                    望岛花艺
# 1   \r\n                                    盐市口
# 2                                          首创光和城
# 3                                  教育培训 教育城 文化培训
# 4                                      客梯0个，货梯0个
#
#                                          loupandizhi miankuan jinshen  \
# 0  \r\n                                    四川省成都市...    3.50米   6.00米
# 1    \r\n                                    龙湖金楠天街       NaN     NaN
# 2                                              首创光和城   20.00米  40.00米
# 3                          锦江区，青羊区，武侯区，成华区，金牛区 郫都区，新   40.00米  20.00米
# 4                                              5.00米    4.00米   3.00米
#
#    cenggao elvator_number service_price  \
# 0    5.50米            NaN         租金已包含
# 1      NaN            NaN           NaN
# 2    5.10米            NaN         租金已包含
# 3    4.50米            NaN     5.00元/㎡·月
# 4  EGO潮流广场      16649.99㎡           24㎡
#
#                                     function_list        release_date  \
# 0                               暖气,中央空调,下水,排污,外摆区   2019/8/4 13:20:41
# 1                                 网络,暖气,停车位,客梯,货梯  2019/8/27 15:06:05
# 2  网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,可明火,排烟,排污,燃气,外摆区  2019/6/15 18:13:59
# 3      网络,暖气,停车位,客梯,货梯,扶梯,中央空调,上水,下水,可明火,排烟,排污,燃气  2019/6/23 10:21:20
# 4                                             NaN   2019/8/2 22:48:20
#
#                                             url
# 0   https://cd.shop.fang.com/zu/1_52957904.html
# 1   https://cd.shop.fang.com/zu/1_52961200.html
# 2  https://cd.shop.fang.com/zu/3_207938226.html
# 3  https://cd.shop.fang.com/zu/3_208016008.html
# 4  https://cd.shop.fang.com/zu/3_208453615.html
#
# [5 rows x 22 columns]
