# %%
import pandas as pd
import numpy as np
import requests
df = pd.read_csv('上海写字楼数据.csv',error_bad_lines=False)

# %%
def replacestr(string):
    string = string.replace('[','')
    string = string.replace(']','')
    string = string.replace("'",'')
    return string

df['loupandizhi'] = df['loupandizhi'].apply(replacestr)

list_location = df['loupandizhi'].value_counts().index.tolist()

dict_location = {}
Key = '6b95b84cab6100c0a6f52c62ece97e4b'
My_key = 'f654d644aeae0e1da847d7ca408f4370'
url_pre = 'https://restapi.amap.com/v3/geocode/geo?key={}&address={}&city={}'
counter = 0
for i in list_location:
    location = i.split(",")[-1].strip()
    url = url_pre.format(Key, location, '上海')
    res = requests.get(url).json()
    if res['status'] == '0':
        dict_location[i] = np.nan
        counter +=1
    else:
        try: 
            dict_location[i] = res['geocodes'][0]['location']
            if counter % 250 == 0:
                print('one batch(250) processed')
        except:
            dict_location[i] = np.nan
            
        counter +=1
# Out:
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed
# one batch(250) processed

# %%
df['location_coords'] = np.nan

counter = 0
for i in list_location:
    counter += 1
    df_temp = df[df['loupandizhi'] == i]
    df_temp_index = df_temp.index.tolist()
    df.iloc[df_temp_index,15] = dict_location[i]
    if counter %50 == 0:
        print('A batch(50) is done')
# Out:
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done
# A batch(50) is done

# %%
df.to_csv('上海写字楼出租地址数据.csv', encoding = 'utf-8-sig',index = False)

# %%
df.head()
# Out:
#   building_type building_year chuzumianji     floor  \
# 0          所在楼层           NaN    1163.39㎡  中区(共58层)
# 1          纯写字楼           NaN       1100㎡  中区(共45层)
# 2          纯写字楼           NaN        182㎡  高区(共25层)
# 3          纯写字楼           NaN        110㎡  中区(共35层)
# 4          纯写字楼           NaN        500㎡  中区(共99层)
#
#                                       loupan_content    loupandizhi  \
# 0  \r\n               \r\n                \r\n   ...  陆家嘴, 中国人寿金融中心
# 1  \r\n               \r\n                \r\n   ...   南京西路, 中信泰富广场
# 2  \r\n               \r\n                \r\n   ...      新天地, 新茂大厦
# 3  \r\n               \r\n                \r\n   ...      陆家嘴, 金砖大厦
# 4  \r\n               \r\n                \r\n   ...    陆家嘴, 上海中心大厦
#
#   price_perunit        release_date   service_price  \
# 0          10.1    2019/9/9 9:18:01  物业费39.00元/平米·月
# 1            11  2019/7/31 10:39:40  物业费35.00元/平米·月
# 2           9.8  2019/8/28 10:47:22  物业费31.50元/平米·月
# 3            10   2019/9/9 10:56:34  物业费39.00元/平米·月
# 4            12  2019/9/10 12:36:16  物业费50.00元/平米·月
#
#                                  titile total_price_10K_permonth  \
# 0        陆家嘴 中国人寿金融中心 本案半层 正对电梯可看江景 近地铁                   352507
# 1  静安 南京西路 中信泰富广场350㎡-2000㎡户型出租 地铁2/7号线                   363000
# 2     房东直租 可15-20人工作 精装全配全包 淮海路商圈 地铁口现房                    53508
# 3             浦东陆家嘴金砖大厦 豪华装修落地窗 一线江景 拎包                    33000
# 4          近金茂大厦，陆家嘴，中国高楼，能与世界接轨的中国超5甲楼                   180000
#
#                                               url xiezilou_level  \
# 0  https://sh.office.fang.com/zu/3_361981853.html             甲级
# 1  https://sh.office.fang.com/zu/3_357807523.html             甲级
# 2  https://sh.office.fang.com/zu/3_360688177.html             甲级
# 3  https://sh.office.fang.com/zu/3_362003967.html             甲级
# 4  https://sh.office.fang.com/zu/3_362102397.html             甲级
#
#                                          xzl_content  zhuangxiu  \
# 0  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...  简装修(不可分割)
# 1  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...   简装修(可分割)
# 2  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...  精装修(不可分割)
# 3  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...  精装修(不可分割)
# 4  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...  精装修(不可分割)
#
#         location_coords
# 0  121.507060,31.242075
# 1  121.455016,31.228339
# 2  121.473500,31.220708
# 3  121.503724,31.232982
# 4  121.505276,31.234188
