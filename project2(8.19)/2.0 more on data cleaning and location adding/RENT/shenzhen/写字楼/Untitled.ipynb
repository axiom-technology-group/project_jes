# %%
import pandas as pd

df = pd.read_csv('xzl_sz_rent.csv',error_bad_lines=False)

# %%
lst = df['loupandizhi'][0].split(',')

loupandizhi = df['loupandizhi'].tolist()
loupandizhilst = []
for i in loupandizhi:
    lst = i.split(',')
    lst1 = []
    for i in lst:

        i = i.replace('\r\n','')
        i = i.replace('写字楼','')
        i = i.strip()
        lst1.append(i)
    loupandizhilst.append(lst1)
df['loupandizhi'] = loupandizhilst

# %%
df.head(3)
# Out:
#   building_type building_year chuzumianji     floor  \
# 0          纯写字楼           NaN        243㎡  低区(共42层)
# 1          纯写字楼           NaN        730㎡  中区(共41层)
# 2          纯写字楼           NaN       1000㎡       NaN
#
#                                       loupan_content         loupandizhi  \
# 0  \r\n               \r\n                \r\n   ...       [福田中心区, 华嵘大厦]
# 1                                                NaN               [车公庙]
# 2  \r\n               \r\n                \r\n   ...  [福田中心区, 卓越世纪中心1号楼]
#
#    price_perunit        release_date   service_price  \
# 0          200.0  2019/8/29 15:38:12  物业费30.00元/平米·月
# 1          198.0   2019/9/3 17:48:49  物业费35.00元/平米·月
# 2          200.0   2019/8/8 11:46:44  物业费10.00元/平米·月
#
#                            titile  total_price_10K_permonth  \
# 0  华嵘大厦东南向仅200元/平，双面采光，精装，视野开阔，急租                     48600
# 1     车公庙5级写字楼，全新精装修，深圳湾海景，地铁口物业！                    144540
# 2      一手物业 卓/越世纪中心 户型方正 三面采光 东南向                    200000
#
#                                               url xiezilou_level  \
# 0  https://sz.office.fang.com/zu/3_221284463.html             甲级
# 1  https://sz.office.fang.com/zu/3_221416266.html             甲级
# 2  https://sz.office.fang.com/zu/3_220669328.html             甲级
#
#                                          xzl_content zhuangxiu
# 0  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...  精装修(可分割)
# 1  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...  毛坯(不可分割)
# 2  \r\n\t\t\t\t\t\r\n\t\t\t\t\t\t房源亮点\r\n\t\t\t\t...  精装修(可分割)

# %%
df.to_csv('深圳写字楼数据.csv',index = False, encoding = 'utf-8-sig')
