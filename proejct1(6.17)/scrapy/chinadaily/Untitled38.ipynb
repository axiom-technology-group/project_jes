# %%
import pandas as pd

# %%
df = pd.read_csv("test.csv",error_bad_lines=False)

# %%
df["url"][2]
# Out:
# 'https://cn.chinadaily.com.cn/a/201906/24/WS5d1037a3a3108375f8f2c0b6.html'

# %%
df
# Out:
#                  column                                            content  \
# 0                  中文首页  当地时间6月22日，澳大利亚霍巴特，大批民众来到沙湾海滩裸泳庆祝南半球冬至日。图片来源：IC...
# 1                  中文首页  6月24日，由已故德国收藏家马丁·波斯特无偿捐赠的45件中国古代艺毯正式入藏上海博物馆。这批...
# 2                  中文原创  中国日报6月24日电 “2019丝路环球旅游盛典”将于8月在宁夏中卫拉开帷幕，主办方将在大漠...
# 3                  中国在线  中新社杭州6月20日电 (郭其钰)杭州互联网法院6月20日首创上线“5G+区块链”涉网执行新...
# 4                  中文首页  6月24日，据北京市气象局官方微博消息，北京市气象台6月24日9时继续发布高温蓝色预警信号。...
# 5                  中国在线  ▲2011年10月22日在关岭化石群国家地质公园内拍摄的海百合化石。　新华社记者刘续摄 一位...
# 6                  中国在线  记者佘颖报道：国家知识产权局知识产权发展研究中心近日发布《2018年中国知识产权发展状况评价...
# 7                  公益频道  社区治理水平影响着城市居民的生活质量。深入推进社区治理创新，构建富有活力和效率的新型基层社会...
# 8                  公益频道  村是脱贫攻坚的重要战场，村级扶贫的成效在很大程度上决定了整个脱贫攻坚的成效。然而，贫困村恰恰...
# 9                  当日要闻  国家主席习近平15日在北京国家会议中心出席亚洲文明对话大会开幕式，并发表题为《深化文明交流互...
# 10                 当日要闻  5月15日，亚洲文化嘉年华活动在北京“鸟巢”举行。新华社记者 沈伯韩 摄 5月15日，亚洲文...
# ...

# %%
df.to_csv("new.csv")

# %%
s ='chinadaily.com.cn |\n          Updated: 2019-06-25 15:01'

# %%
s1 = s.split('Updated:')

# %%
s1[1].strip()
# Out:
# '2019-06-25 15:01'

# %%
s1[0].replace(" |\n","")
# Out:
# 'chinadaily.com.cn          '
